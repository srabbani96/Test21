# %%
import pandas as  pd
df = pd.read_csv("AppleStore.csv")

# %%
df.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.count()
# Out:
# id                  7197
# track_name          7197
# size_bytes          7197
# currency            7197
# price               7197
# rating_count_tot    7197
# rating_count_ver    7197
# user_rating         7197
# user_rating_ver     7197
# ver                 7197
# cont_rating         7197
# prime_genre         7197
# sup_devices.num     7197
# ipadSc_urls.num     7197
# lang.num            7197
# vpp_lic             7197
# dtype: int64

# %%
df.rating_count_tot.head()
# Out:
# 0     21292
# 1    161065
# 2    188583
# 3    262241
# 4    985920
# Name: rating_count_tot, dtype: int64

# %%
df.track_name.unique()
# Out:
# array(['PAC-MAN Premium', 'Evernote - stay organized',
#        'WeatherBug - Local Weather, Radar, Maps, Alerts', ...,
#        'Bret Michaels Emojis + Lyric Keyboard',
#        'VR Roller Coaster World - Virtual Reality',
#        'Escape the Sweet Shop Series'], dtype=object)

# %%
df= df.sort_values('rating_count_tot',ascending = False)
subset_df= df[:10]
print(subset_df.track_name,subset_df.rating_count_tot,"bar","TOP 10 Apps","APP NAME","RATING COUNT (TOTAL)",True, -60)
# Out:
# 16                     Facebook
# 519                   Instagram
# 1346             Clash of Clans
# 707                  Temple Run
# 7       Pandora - Music & Radio
# 755                   Pinterest
# 4                         Bible
# 1493           Candy Crush Saga
# 178               Spotify Music
# 275                 Angry Birds
# Name: track_name, dtype: object 16      2974676
# 519     2161558
# 1346    2130805
# 707     1724546
# 7       1126879
# 755     1061624
# 4        985920
# 1493     961794
# 178      878563
# 275      824451
# Name: rating_count_tot, dtype: int64 bar TOP 10 Apps APP NAME RATING COUNT (TOTAL) True -60

# %%
df.sort_values("rating_count_tot").tail(10)
# Out:
#              id               track_name  size_bytes currency  price  \
# 275   343200656              Angry Birds   175966208      USD    0.0
# 178   324684580            Spotify Music   132510720      USD    0.0
# 1493  553834731         Candy Crush Saga   222846976      USD    0.0
# 4     282935706                    Bible    92774400      USD    0.0
# 755   429047995                Pinterest    74778624      USD    0.0
# 7     284035177  Pandora - Music & Radio   130242560      USD    0.0
# 707   420009108               Temple Run    65921024      USD    0.0
# 1346  529479190           Clash of Clans   116476928      USD    0.0
# 519   389801252                Instagram   113954816      USD    0.0
# 16    284882215                 Facebook   389879808      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 275             824451               107          4.5              3.0
# ...

# %%
df.sort_values('user rating').head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-530ad77cd54d> in <module>
# ----> 1 df.sort_values('user rating').head(10)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4419             by = by[0]
#    4420             k = self._get_label_or_level_values(by, axis=axis,
# -> 4421                                                 stacklevel=stacklevel)
#    4422
#    4423             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 'user rating'

# %%
df[df.cont_rating=="17+"]
# Out:
#               id                                         track_name  \
# 1182   500116670                                 Clear Vision (17+)
# 12     284815942               Google – Search made just for mobile
# 3086   930574573         Sniper 3D Assassin: Shoot to Kill Gun Game
# 221    333903271                                            Twitter
# 92     305343404                                             Tumblr
# 1433   544007664    YouTube - Watch Videos, Music, and Live Streams
# 197    328415391                               Yahoo Fantasy Sports
# 86     303849934                                     Beer Pong Game
# 1682   583222866                                Deer Hunter Classic
# 624    406719683                                           GasBuddy
# 1462   547702041                                             Tinder
# 1817   606190854                                         Iron Force
# 999    471063940                    Call of Duty: Black Ops Zombies
# ...

# %%
df[df.cont_rating=="4+"]
# Out:
#               id                                         track_name  \
# 16     284882215                                           Facebook
# 4      282935706                                              Bible
# 1493   553834731                                   Candy Crush Saga
# 275    343200656                                        Angry Birds
# 348    362949845                                Fruit Ninja Classic
# 343    359917414                                          Solitaire
# 990    469369175                                         CSR Racing
# 1218   506627515                                            Hay Day
# 47     293778748                                            PAC-MAN
# 265    341232718     Calorie Counter & Diet Tracker by MyFitnessPal
# 829    440045374                                         DragonVale
# 53     295646461      The Weather Channel: Forecast, Radar & Alerts
# 1104   487119327                                        Head Soccer
# ...

# %%
df[df.cont_rating=="9+"]
# Out:
#               id                                      track_name  size_bytes  \
# 1346   529479190                                  Clash of Clans   116476928
# 707    420009108                                      Temple Run    65921024
# 1246   512939461                                  Subway Surfers   156038144
# 3042   924373886             Crossy Road - Endless Arcade Hopper   165471232
# 1052   479516143                       Minecraft: Pocket Edition   147787776
# 1775   596402997                      Despicable Me: Minion Rush   147123200
# 302    350642635                              Plants vs. Zombies   105379840
# 925    457446957                                 Jetpack Joyride   108813312
# 1613   572395608                                    Temple Run 2   158025728
# 1781   597986893                           Plants vs. Zombies™ 2    98507776
# 4613  1053012308                                    Clash Royale   114408448
# ...

# %%
df[df.cont_rating=="12+"]
# Out:
#               id                                         track_name  \
# 519    389801252                                          Instagram
# 7      284035177                            Pandora - Music & Radio
# 755    429047995                                          Pinterest
# 178    324684580                                      Spotify Music
# 1634   575658129                           Injustice: Gods Among Us
# 971    466965151                                 The Sims™ FreePlay
# 317    352683833   Groupon - Deals, Coupons & Discount Shopping App
# 719    422667065                    Tiny Tower - Free City Building
# 18     284993459  Shazam - Discover music, artists, videos & lyrics
# 2602   860822992                          Kim Kardashian: Hollywood
# 498    387428400                                     Infinity Blade
# 872    447188370                                           Snapchat
# 1933   640111933                                       Pixel Gun 3D
# ...

# %%
Students= [' Distinction',' First Class', 'Second Class', 'Third Class',' Failed ']
avg_marks = [75,65,55,50]
Marks = [100,90,80,70,40]
width= 0.3
plt.bar(Student,Marks , color ='r', width=2.5)
plt.bar(avg_marks, Student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-7bcd78de87ea> in <module>
#       3 Marks = [100,90,80,70,40]
#       4 width= 0.3
# ----> 5 plt.bar(Student,Marks , color ='r', width=2.5)
#       6 plt.bar(avg_marks, Student)
#
# NameError: name 'plt' is not defined

# %%
np.random.rand(5)
np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-54c4f978e61b> in <module>
# ----> 1 np.random.rand(5)
#       2 np
#
# NameError: name 'np' is not defined

# %%
import numpy as np
np.random.rand(2000)
# Out:
# array([0.41070086, 0.29960251, 0.51288321, ..., 0.56391887, 0.66830444,
#        0.08379995])

# %%
x= np.arange (2000)
y= np.arange(0)

# %%
import random
print("Printing random number using random.random(2000)")
print(random.random())
# Out:
# Printing random number using random.random(2000)
# 0.2103753766254528

# %%
#random.randrange(0, 2000):
for i in range(100):
    cnt=0
    if i>=75:
        print (i,"as distinction")
        cnt+=1
   
        if i>60:
            cnt+=1
            len(i)
            
        if i>50:
             cnt+=1
                len(i)
            else:
                len(i)
    elif i<35:
# Out:
#   File "<tokenize>", line 15
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
random.randrange(2000)
# Out:
# 378
